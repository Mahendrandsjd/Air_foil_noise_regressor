# %%
# Import all the necessery packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Import csv file

df=pd.read_csv("C:\\Users\\vishn\\OneDrive\\Documents\\machine learning\\Airfoil_self_noise.csv",sep="\t",header=None)

# %%
# Creating a dataframe

q=pd.DataFrame(df)
print(q)
# Out:
#          0     1       2     3         4        5
# 0      800   0.0  0.3048  71.3  0.002663  126.201
# 1     1000   0.0  0.3048  71.3  0.002663  125.201
# 2     1250   0.0  0.3048  71.3  0.002663  125.951
# 3     1600   0.0  0.3048  71.3  0.002663  127.591
# 4     2000   0.0  0.3048  71.3  0.002663  127.461
# ...    ...   ...     ...   ...       ...      ...
# 1498  2500  15.6  0.1016  39.6  0.052849  110.264
# 1499  3150  15.6  0.1016  39.6  0.052849  109.254
# 1500  4000  15.6  0.1016  39.6  0.052849  106.604
# 1501  5000  15.6  0.1016  39.6  0.052849  106.224
# 1502  6300  15.6  0.1016  39.6  0.052849  104.204
#
# [1503 rows x 6 columns]

# %%
# Display first five lines of the dataset

df.head()
# Out:
#       0    1       2     3         4        5
# 0   800  0.0  0.3048  71.3  0.002663  126.201
# 1  1000  0.0  0.3048  71.3  0.002663  125.201
# 2  1250  0.0  0.3048  71.3  0.002663  125.951
# 3  1600  0.0  0.3048  71.3  0.002663  127.591
# 4  2000  0.0  0.3048  71.3  0.002663  127.461

# %%
# Give column names

df.columns=["Frequency","Angle of attack","chord length","Free-stream velocity","Suction side","Pressure level"]

# %%
df.head()
# Out:
#    Frequency  Angle of attack  chord length  Free-stream velocity  \
# 0        800              0.0        0.3048                  71.3
# 1       1000              0.0        0.3048                  71.3
# 2       1250              0.0        0.3048                  71.3
# 3       1600              0.0        0.3048                  71.3
# 4       2000              0.0        0.3048                  71.3
#
#    Suction side  Pressure level
# 0      0.002663         126.201
# 1      0.002663         125.201
# 2      0.002663         125.951
# 3      0.002663         127.591
# 4      0.002663         127.461

# %%
# 'shape' function returns a tuple that gives the total number of rows and columns in the data

q.shape
# Out:
# (1503, 6)

# %%
# 'dtypes' provides the data type for each column

q.dtypes
# Out:
# Frequency                 int64
# Angle of attack         float64
# chord length            float64
# Free-stream velocity    float64
# Suction side            float64
# Pressure level          float64
# dtype: object

# %%
# convert categorical variables

pd.get_dummies(df)
# Out:
#       Frequency  Angle of attack  chord length  Free-stream velocity  \
# 0           800              0.0        0.3048                  71.3
# 1          1000              0.0        0.3048                  71.3
# 2          1250              0.0        0.3048                  71.3
# 3          1600              0.0        0.3048                  71.3
# 4          2000              0.0        0.3048                  71.3
# ...         ...              ...           ...                   ...
# 1498       2500             15.6        0.1016                  39.6
# 1499       3150             15.6        0.1016                  39.6
# 1500       4000             15.6        0.1016                  39.6
# 1501       5000             15.6        0.1016                  39.6
# 1502       6300             15.6        0.1016                  39.6
#
#       Suction side  Pressure level
# 0         0.002663         126.201
# 1         0.002663         125.201
# ...

# %%
# Count the null values

df.isnull().sum()
# Out:
# Frequency               0
# Angle of attack         0
# chord length            0
# Free-stream velocity    0
# Suction side            0
# Pressure level          0
# dtype: int64

# %%
#find maximum values in each column

maxvalue=q.max()
print(maxvalue)
# Out:
# Frequency               20000.000000
# Angle of attack            22.200000
# chord length                0.304800
# Free-stream velocity       71.300000
# Suction side                0.058411
# Pressure level            140.987000
# dtype: float64

# %%
#find minimum values in each column

minvalue=q.min()
print(minvalue)
# Out:
# Frequency               200.000000
# Angle of attack           0.000000
# chord length              0.025400
# Free-stream velocity     31.700000
# Suction side              0.000401
# Pressure level          103.380000
# dtype: float64

# %%
# by default the describe function returns the summary of numerical variables

q.describe()
# Out:
#           Frequency  Angle of attack  chord length  Free-stream velocity  \
# count   1503.000000      1503.000000   1503.000000           1503.000000
# mean    2886.380572         6.782302      0.136548             50.860745
# std     3152.573137         5.918128      0.093541             15.572784
# min      200.000000         0.000000      0.025400             31.700000
# 25%      800.000000         2.000000      0.050800             39.600000
# 50%     1600.000000         5.400000      0.101600             39.600000
# 75%     4000.000000         9.900000      0.228600             71.300000
# max    20000.000000        22.200000      0.304800             71.300000
#
#        Suction side  Pressure level
# count   1503.000000     1503.000000
# mean       0.011140      124.835943
# std        0.013150        6.898657
# min        0.000401      103.380000
# 25%        0.002535      120.191000
# 50%        0.004957      125.721000
# 75%        0.015576      129.995500
# ...

# %%
# calculate the first quartile
Q1 = q.quantile(0.25)

# calculate the third quartile
Q3 = q.quantile(0.75)

# Interquartile Range (IQR) is defined as the difference between the third and first quartile
# calculate IQR
IQR = Q3 - Q1

# print the IQR
print(IQR)
# Out:
# Frequency               3200.000000
# Angle of attack            7.900000
# chord length               0.177800
# Free-stream velocity      31.700000
# Suction side               0.013041
# Pressure level             9.804500
# dtype: float64

# %%
#find duplicate values in the dataset

q.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1498    False
# 1499    False
# 1500    False
# 1501    False
# 1502    False
# Length: 1503, dtype: bool

# %%
# Allocate independent variables to x
x=df.iloc[:, :-1]
# Allocate dependent variables to y
y=df.iloc[:,-1]

# %%
x.head()
# Out:
#    Frequency  Angle of attack  chord length  Free-stream velocity  \
# 0        800              0.0        0.3048                  71.3
# 1       1000              0.0        0.3048                  71.3
# 2       1250              0.0        0.3048                  71.3
# 3       1600              0.0        0.3048                  71.3
# 4       2000              0.0        0.3048                  71.3
#
#    Suction side
# 0      0.002663
# 1      0.002663
# 2      0.002663
# 3      0.002663
# 4      0.002663

# %%
y.head()
# Out:
# 0    126.201
# 1    125.201
# 2    125.951
# 3    127.591
# 4    127.461
# Name: Pressure level, dtype: float64

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
sns.pairplot(x_train)

# %%
#Using LinearRegression

from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Calculating y_train_pred values from x_train

y_train_pred=regressor.predict(x_train)
y_train_pred
# Out:
# array([133.39595155, 125.04439465, 119.65333896, ..., 125.1226852 ,
#        128.35873848, 121.4758521 ])

# %%
# Calcutaing y_pred values from x_test

y_pred=regressor.predict(x_test)
print(y_pred)
# Out:
# [126.06691865 120.41085478 118.00804019 128.94849956 124.67831119
#  129.2134722  120.30439997 133.19474628 119.55523209 126.13068429
#  125.12584075 126.5914984  132.4177449  121.15656356 123.92837591
#  119.04565814 128.74637116 122.95143954 118.24095906 125.09301031
#  122.18488209 127.2736726  127.23347226 125.91654147 128.75561867
#  122.78255207 116.54782156 126.84770113 128.10673918 126.2099324
#  129.77167557 123.87894039 109.58124096 127.41200355 127.87469044
#  129.66625761 119.74885492 103.77831099 126.97818041 129.66804555
#  131.88125049 122.99280613 124.9078632  118.65659782 116.40745728
#  131.21924887 126.73553244 129.99216165 131.67640563 123.47266869
#  120.69690821 124.36442428 118.4369104  124.70707854 122.32860906
#  123.66112096 113.63563365 125.6930122  124.26492446 120.27182181
#  125.37290887 125.41130588 127.8118806  130.3869802  122.78826629
#  128.35529521 128.09703771 127.92335    128.67884182 129.14056156
# ...

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
y_train_pred=regressor.predict(x_train)
rmse = np.sqrt(mean_squared_error(y_train,y_train_pred))
r2 = r2_score(y_train,y_train_pred)
mae = mean_absolute_error(y_train,y_train_pred)
print("For training data set")
print("Mean absolute error:",mae)
print("Root mean square error",rmse)
print("R2 score:",r2)
y_pred=regressor.predict(x_test)
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
print("For training data set")
print("Mean absolute error:",mae)
print("Root mean square error",rmse)
print("R2 score:",r2)
# Out:
# For training data set
# Mean absolute error: 3.765235804080878
# Root mean square error 4.859881559915915
# R2 score: 0.5047490146008984
# For training data set
# Mean absolute error: 3.545248297264668
# Root mean square error 4.55687409257963
# R2 score: 0.5585557273101007

# %%
plt.scatter(y_test,y_pred,c='r')
plt.plot(y_test,y_test,c='blue')
plt.xlabel('y_test')
plt.ylabel('y_pred')
plt.show()

# %%
regressor.predict([[800,0.0,0.3048,71.3,0.002663]])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([127.45318148])

# %%
#Using RandomForestRegressor

from sklearn.ensemble import RandomForestRegressor
regr=RandomForestRegressor(max_depth=3, random_state=0, n_estimators=100)
regr=regr.fit(x_train,y_train)

# %%
# Calculating y_train_pred values from x_train

y_train_pred=regr.predict(x_train)
y_train_pred
# Out:
# array([129.07349846, 127.31061006, 120.28619237, ..., 126.15330928,
#        127.67674251, 126.18864616])

# %%
# Calcutaing y_pred values from x_test

y_pred=regr.predict(x_test)
y_pred
# Out:
# array([126.77183015, 116.94361074, 120.30842905, 126.21166646,
#        124.26315708, 127.38879688, 118.30904033, 128.09257989,
#        123.64426636, 121.4286685 , 126.95370253, 129.31496718,
#        128.09257989, 126.78769315, 126.92483758, 117.24419004,
#        128.1455615 , 126.77183015, 120.42196349, 125.30130548,
#        120.39483091, 126.76768281, 124.02800467, 126.15330928,
#        127.44676635, 126.83234891, 120.54638289, 128.1010049 ,
#        127.24906997, 127.30891245, 127.99312104, 124.13118419,
#        115.20685973, 125.8657067 , 128.17176991, 127.91527355,
#        120.62766147, 116.56281235, 127.27212084, 127.91527355,
#        128.40122479, 125.21802052, 125.37207048, 120.69290262,
#        117.24419004, 127.61464028, 128.08306249, 127.75699336,
#        128.03099136, 126.92483758, 124.6217252 , 124.79982685,
#        125.45435371, 126.3889724 , 121.09526265, 118.30904033,
#        122.49272471, 127.30891245, 118.30904033, 124.3889348 ,
# ...

# %%
y_train_pred=regr.predict(x_train)
rmse = np.sqrt(mean_squared_error(y_train,y_train_pred))
r2 = r2_score(y_train,y_train_pred)
mae = mean_absolute_error(y_train,y_train_pred)
print("For training data set")
print("Mean absolute error:",mae)
print("Root mean square error",rmse)
print("R2 score:",r2)
y_pred=regr.predict(x_test)
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
print("For training data set")
print("Mean absolute error:",mae)
print("Root mean square error",rmse)
print("R2 score:",r2)
# Out:
# For training data set
# Mean absolute error: 3.5730501059948647
# Root mean square error 4.461071810202884
# R2 score: 0.582696135816118
# For training data set
# Mean absolute error: 3.580102419028613
# Root mean square error 4.549451875786834
# R2 score: 0.5599926012095408

# %%
plt.scatter(y_test,y_pred,c='r')
plt.plot(y_test,y_test,c='blue')
plt.xlabel('y_test')
plt.ylabel('y_pred')
plt.show()

# %%
regr.predict([[800,0.0,0.3048,71.3,0.002663]])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([128.08306249])

# %%
#Using DecisionTreeRegressor

from sklearn.tree import DecisionTreeRegressor
retr = DecisionTreeRegressor(random_state=0)
retr = retr.fit(x_train,y_train)

# %%
# Calculating y_train_pred values from x_train

y_train_pred=retr.predict(x_train)
y_train_pred
# Out:
# array([127.206, 136.284, 117.504, ..., 140.987, 130.777, 122.149])

# %%
# Calcutaing y_pred values from x_test

y_pred=retr.predict(x_test)
y_pred
# Out:
# array([129.867, 117.976, 110.447, 115.846, 129.285, 123.565, 119.535,
#        124.156, 116.295, 125.603, 125.319, 132.184, 127.947, 117.911,
#        126.959, 115.298, 129.038, 134.227, 115.304, 116.066, 120.513,
#        132.588, 128.536, 134.247, 130.541, 121.659, 115.659, 139.918,
#        130.049, 131.491, 127.251, 120.193, 104.13 , 126.826, 133.48 ,
#        130.374, 115.659, 112.768, 128.296, 126.886, 132.095, 124.244,
#        135.324, 121.657, 111.959, 134.226, 125.992, 129.953, 126.78 ,
#        129.465, 124.717, 123.865, 119.375, 127.315, 121.627, 120.472,
#        117.087, 132.358, 121.431, 119.174, 120.058, 133.294, 128.296,
#        134.236, 126.644, 124.077, 128.244, 131.808, 133.201, 112.506,
#        129.308, 125.872, 126.291, 132.43 , 124.214, 125.203, 119.35 ,
#        125.452, 133.649, 129.953, 131.074, 131.186, 115.52 , 123.037,
#        129.964, 118.922, 128.939, 122.724, 135.191, 123.82 , 131.889,
# ...

# %%
y_train_pred=retr.predict(x_train)
rmse = np.sqrt(mean_squared_error(y_train,y_train_pred))
r2 = r2_score(y_train,y_train_pred)
mae = mean_absolute_error(y_train,y_train_pred)
print("For training data set")
print("Mean absolute error:",mae)
print("Root mean square error",rmse)
print("R2 score:",r2)
y_pred=retr.predict(x_test)
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
print("For training data set")
print("Mean absolute error:",mae)
print("Root mean square error",rmse)
print("R2 score:",r2)
# Out:
# For training data set
# Mean absolute error: 0.0
# Root mean square error 0.0
# R2 score: 1.0
# For training data set
# Mean absolute error: 1.636388704318937
# Root mean square error 2.2654245170662652
# R2 score: 0.8908959126091601

# %%
plt.scatter(y_test,y_pred,c='r')
plt.plot(y_test,y_test,c='blue')
plt.xlabel('y_test')
plt.ylabel('y_pred')
plt.show()

# %%
retr.predict([[800,0.0,0.3048,71.3,0.002663]])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([126.201])
